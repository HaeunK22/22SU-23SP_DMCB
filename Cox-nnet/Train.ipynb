# %%
import os 
import pandas as pd 
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from Code_manual import Coxnnet, PartialNLL
from lifelines.utils import concordance_index
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import warnings
warnings.filterwarnings('ignore')

# %%
os.getcwd()
# Out:
# 'd:\\Survival Analysis\\Cox-nnet'

# %% [markdown]
# Data Loading

# %%
expr_data = pd.read_table("./KIRC_expr.tsv", header=None)
# print(expr_data.shape)   # output : (540,19962)

time_data = pd.read_table("./KIRC_time.tsv", header=None)
# time_data.shape # output : (540,1)

observed_data = pd.read_table("./KIRC_event.tsv", header=None)
# observed_data.shape # output : (540,1)

# %%
map_dict = {'DECEASED' : 1,
            'LIVING' : 0}
observed_data = observed_data[0].apply(lambda x : map_dict[x])

# %%
X = torch.tensor(np.array(expr_data), dtype=torch.float)
time = torch.tensor(time_data.to_numpy(), dtype=torch.long)
observed = torch.tensor(observed_data.to_numpy(), dtype=torch.float)
train_idx, test_idx, _, _ = train_test_split(np.arange(X.shape[0]), observed, test_size=0.3, random_state=25)

train_X = X[train_idx,:]
test_X = X[test_idx,:]

train_time = time[train_idx]
test_time = time[test_idx]

train_observed = observed[train_idx]
test_observed = observed[test_idx]

# %%
cuda = True if torch.cuda.is_available() else False
if cuda:
    device = torch.device(f'cuda:{0}' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# Training

# %%
from torch import nn
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda

class TrainDataset(Dataset):
    def __init__(self):
        self.x_data = torch.tensor(train_X, device=device)
        self.time_data = torch.tensor(train_time, device=device)
        self.observed_data = torch.tensor(train_observed, device=device)
    
    def __len__(self):
        return len(self.x_data)
    
    def __getitem__(self, index):
        x = torch.tensor(self.x_data[index]).clone().detach()
        time = torch.tensor(self.time_data[index]).clone().detach()
        observed = torch.tensor(self.observed_data[index]).clone().detach()
        return x, time, observed
    
class TestDataset(Dataset):
    def __init__(self):
        self.x_data = torch.tensor(test_X, device=device)
        self.time_data = torch.tensor(test_time, device=device)
        self.observed_data = torch.tensor(test_observed, device=device)
    
    def __len__(self):
        return len(self.x_data)
    
    def __getitem__(self, index):
        x = torch.tensor(self.x_data[index]).clone().detach()
        time = torch.tensor(self.time_data[index]).clone().detach()
        observed = torch.tensor(self.observed_data[index]).clone().detach()
        return x, time, observed
    
training_data = TrainDataset()
test_data = TestDataset()

train_dataloader = DataLoader(training_data, batch_size = training_data.__len__())
test_dataloader = DataLoader(test_data, batch_size = test_data.__len__())

# %%
hidden_dim = 500
model = Coxnnet(train_X.shape[1], hidden_dim)
model = model.to(device)

learning_rate = 5e-5
epochs = 300

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
loss_fn = PartialNLL()

loss_axis = []
cindex_train = []
cindex_test = []

def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, time, observed) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, time, observed)

        # Backpropagation
        optimizer.zero_grad()   # bc/ gradients by default add up; to prevent double counting.
        loss.backward() # deposits gradients
        optimizer.step()    # adjust parameters with gradients
        
        train_perf = 0
        train_perf = concordance_index(event_times = time.cpu().detach().numpy(),
                                       event_observed = observed.cpu().detach().numpy(),
                                       predicted_scores = -pred.cpu().detach().numpy())
        print(f"Train Accuracy: {train_perf}")
        print(f"Train Loss: {loss.item()}\n")
        # print(f"Type of loss: {type(loss.item())}") # output: float
        loss_axis.append(loss.item())
        cindex_train.append(train_perf)

# iterate over test dataset to check model performance
def test_loop(dataloader, model):
    size = len(dataloader.dataset)
    test_perf = 0

    with torch.no_grad():
        for X, time, observed in dataloader:
            pred = model.forward(X)
            # print(f"event_times shape: {time.numpy().shape}")
            # print(f"predicted shape: {pred.numpy().shape}\n")
            test_perf = concordance_index(event_times = time.cpu().detach().numpy(),
                                          event_observed = observed.cpu().detach().numpy(),
                                          predicted_scores = -pred.cpu().detach().numpy())

    print(f"Test Accuracy: {test_perf}\n")
    cindex_test.append(test_perf)

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model)
# Out:
# Epoch 1
# -------------------------------
# Train Accuracy: 0.5095158727082445
# Train Loss: 5.558159844240557
#
# Test Accuracy: 0.5757526968282081
#
# Epoch 2
# -------------------------------
# Train Accuracy: 0.5862242722586146
# Train Loss: 5.385423230715982
#
# Test Accuracy: 0.617452906134278
#
# Epoch 3
# -------------------------------
# Train Accuracy: 0.5952168688708864
# Train Loss: 5.376407012053847
#
# Test Accuracy: 0.5794558042183223
#
# Epoch 4
# -------------------------------
# Train Accuracy: 0.5825031977983642
# Train Loss: 5.402684571889185
#
# Test Accuracy: 0.6316213170181936
#
# Epoch 5
# -------------------------------
# Train Accuracy: 0.6208767781696966
# Train Loss: 5.3270779923082685
#
# Test Accuracy: 0.6230880695540171
#
# Epoch 6
# -------------------------------
# Train Accuracy: 0.6071165549052289
# Train Loss: 5.377300211387693
#
# Test Accuracy: 0.6438576718724843
#
# Epoch 7
# -------------------------------
# Train Accuracy: 0.6337842552036901
# Train Loss: 5.2629596244986665
#
# Test Accuracy: 0.5725326034454999
#
# Epoch 8
# -------------------------------
# Train Accuracy: 0.6093259428660026
# Train Loss: 5.351085516030586
#
# Test Accuracy: 0.5477378843986476
#
# Epoch 9
# -------------------------------
# Train Accuracy: 0.6363812550874065
# Train Loss: 5.311165718168217
#
# Test Accuracy: 0.5786507808726453
#
# Epoch 10
# -------------------------------
# Train Accuracy: 0.6633978061165161
# Train Loss: 5.219122185004051
#
# Test Accuracy: 0.5855739816454677
#
# Epoch 11
# -------------------------------
# Train Accuracy: 0.6632815225396334
# Train Loss: 5.245642612050377
#
# Test Accuracy: 0.5968443084849461
#
# Epoch 12
# -------------------------------
# Train Accuracy: 0.6688243730377147
# Train Loss: 5.238298411931345
#
# Test Accuracy: 0.630977298341652
#
# Epoch 13
# -------------------------------
# Train Accuracy: 0.693980386836699
# Train Loss: 5.1470929532024705
#
# Test Accuracy: 0.5986153598454356
#
# Epoch 14
# -------------------------------
# Train Accuracy: 0.6658397612310555
# Train Loss: 5.2323152475813375
#
# Test Accuracy: 0.5912091450652069
#
# Epoch 15
# -------------------------------
# Train Accuracy: 0.6691732237683631
# Train Loss: 5.2173179037183095
#
# Test Accuracy: 0.6354854290774432
#
# Epoch 16
# -------------------------------
# Train Accuracy: 0.676615372688864
# Train Loss: 5.196146120085538
#
# Test Accuracy: 0.6541619706971502
#
# Epoch 17
# -------------------------------
# Train Accuracy: 0.6951044614132331
# Train Loss: 5.138115031026606
#
# Test Accuracy: 0.607953630655289
#
# Epoch 18
# -------------------------------
# Train Accuracy: 0.6699872088065429
# Train Loss: 5.2164166854513185
#
# Test Accuracy: 0.6535179520206086
#
# Epoch 19
# -------------------------------
# Train Accuracy: 0.6970425210279468
# Train Loss: 5.118293284983194
#
# Test Accuracy: 0.6208340041861214
#
# Epoch 20
# -------------------------------
# Train Accuracy: 0.7189038334819179
# Train Loss: 5.092972353317907
#
# Test Accuracy: 0.6197069715021736
#
# Epoch 21
# -------------------------------
# Train Accuracy: 0.7136710725221908
# Train Loss: 5.045332718848588
#
# Test Accuracy: 0.5952342617935921
#
# Epoch 22
# -------------------------------
# Train Accuracy: 0.6773130741501608
# Train Loss: 5.128759675632522
#
# Test Accuracy: 0.6414426018354532
#
# Epoch 23
# -------------------------------
# Train Accuracy: 0.679871312841583
# Train Loss: 5.1887331822267315
#
# Test Accuracy: 0.6499758492996297
#
# Epoch 24
# -------------------------------
# Train Accuracy: 0.6777006860731036
# Train Loss: 5.119947001009504
#
# Test Accuracy: 0.6425696345194011
#
# Epoch 25
# -------------------------------
# Train Accuracy: 0.7003759835652544
# Train Loss: 5.1469327531207405
#
# Test Accuracy: 0.6048945419417163
#
# Epoch 26
# -------------------------------
# Train Accuracy: 0.6828946858405365
# Train Loss: 5.147324248122295
#
# Test Accuracy: 0.6261471582675897
#
# Epoch 27
# -------------------------------
# Train Accuracy: 0.7029729834489709
# Train Loss: 5.088926056605709
#
# Test Accuracy: 0.6240540975688295
#
# Epoch 28
# -------------------------------
# Train Accuracy: 0.705802550486453
# Train Loss: 5.109616552080802
#
# Test Accuracy: 0.6813717597810337
#
# Epoch 29
# -------------------------------
# Train Accuracy: 0.7081282220241094
# Train Loss: 5.0723253209374475
#
# Test Accuracy: 0.6351634197391725
#
# Epoch 30
# -------------------------------
# Train Accuracy: 0.7111128338307686
# Train Loss: 5.071591387775045
#
# Test Accuracy: 0.6836258251489293
#
# Epoch 31
# -------------------------------
# Train Accuracy: 0.7158029380983759
# Train Loss: 5.063654229464838
#
# Test Accuracy: 0.5887940750281758
#
# Epoch 32
# -------------------------------
# Train Accuracy: 0.7136710725221908
# Train Loss: 5.032054893253096
#
# Test Accuracy: 0.6905490259217517
#
# Epoch 33
# -------------------------------
# Train Accuracy: 0.7421217876661886
# Train Loss: 4.991104405935985
#
# Test Accuracy: 0.63419739172436
#
# Epoch 34
# -------------------------------
# Train Accuracy: 0.7139424008682507
# Train Loss: 5.073153068225677
#
# Test Accuracy: 0.6145548220898406
#
# Epoch 35
# -------------------------------
# Train Accuracy: 0.7434009070118996
# Train Loss: 4.991253615805294
#
# Test Accuracy: 0.6507808726453067
#
# Epoch 36
# -------------------------------
# Train Accuracy: 0.7313074150160859
# Train Loss: 4.986394374288537
#
# Test Accuracy: 0.619867976171309
#
# Epoch 37
# -------------------------------
# Train Accuracy: 0.7330516686693282
# Train Loss: 4.970322822039661
#
# Test Accuracy: 0.6074706166478828
#
# Epoch 38
# -------------------------------
# Train Accuracy: 0.7530136827008799
# Train Loss: 4.956787607395966
#
# Test Accuracy: 0.6166478827886008
#
# Epoch 39
# -------------------------------
# Train Accuracy: 0.7479359665103299
# Train Loss: 4.984568771613139
#
# Test Accuracy: 0.6915150539365642
#
# Epoch 40
# -------------------------------
# Train Accuracy: 0.7472770262413272
# Train Loss: 4.962711815790445
#
# Test Accuracy: 0.6470777652551924
#
# Epoch 41
# -------------------------------
# Train Accuracy: 0.7360362804759875
# Train Loss: 5.025209127728785
#
# Test Accuracy: 0.6573820640798583
#
# Epoch 42
# -------------------------------
# Train Accuracy: 0.7634404434280398
# Train Loss: 4.913471979728448
#
# Test Accuracy: 0.6089196586701014
#
# Epoch 43
# -------------------------------
# Train Accuracy: 0.7737121593860227
# Train Loss: 4.892426915510074
#
# Test Accuracy: 0.6382225084527451
#
# Epoch 44
# -------------------------------
# Train Accuracy: 0.7407263847435948
# Train Loss: 5.042278350712238
#
# Test Accuracy: 0.6367734664305265
#
# Epoch 45
# -------------------------------
# Train Accuracy: 0.7233613705957596
# Train Loss: 5.023068306519399
#
# Test Accuracy: 0.6176139108034133
#
# Epoch 46
# -------------------------------
# Train Accuracy: 0.754447846815768
# Train Loss: 4.946695784483248
#
# Test Accuracy: 0.6591531154403478
#
# Epoch 47
# -------------------------------
# Train Accuracy: 0.7391371758595294
# Train Loss: 5.0211529366153025
#
# Test Accuracy: 0.6765416197069715
#
# Epoch 48
# -------------------------------
# Train Accuracy: 0.7590216675064925
# Train Loss: 4.977714347408937
#
# Test Accuracy: 0.6229270648848817
#
# Epoch 49
# -------------------------------
# Train Accuracy: 0.7258420869025931
# Train Loss: 5.0194765589936505
#
# Test Accuracy: 0.6187409434873611
#
# Epoch 50
# -------------------------------
# Train Accuracy: 0.7388658475134695
# Train Loss: 5.046387309042939
#
# Test Accuracy: 0.6224440508774755
#
# Epoch 51
# -------------------------------
# Train Accuracy: 0.7400286832822978
# Train Loss: 4.967600296167317
#
# Test Accuracy: 0.6077926259861536
#
# Epoch 52
# -------------------------------
# Train Accuracy: 0.7657661149656964
# Train Loss: 4.880160902687509
#
# Test Accuracy: 0.6966672033488971
#
# Epoch 53
# -------------------------------
# Train Accuracy: 0.7212682662118687
# Train Loss: 5.043524215441889
#
# Test Accuracy: 0.6425696345194011
#
# Epoch 54
# -------------------------------
# Train Accuracy: 0.7315399821698515
# Train Loss: 4.988505729170811
#
# Test Accuracy: 0.5929801964256963
#
# Epoch 55
# -------------------------------
# Train Accuracy: 0.7483623396255669
# Train Loss: 4.952739089090139
#
# Test Accuracy: 0.6998872967316052
#
# Epoch 56
# -------------------------------
# Train Accuracy: 0.7692158610798868
# Train Loss: 4.9300425729396435
#
# Test Accuracy: 0.6391885364675576
#
# Epoch 57
# -------------------------------
# Train Accuracy: 0.7475871157796814
# Train Loss: 4.983426998722214
#
# Test Accuracy: 0.606343583963935
#
# Epoch 58
# -------------------------------
# Train Accuracy: 0.7514632350091088
# Train Loss: 4.942294085465375
#
# Test Accuracy: 0.6807277411044921
#
# Epoch 59
# -------------------------------
# Train Accuracy: 0.7004147447575487
# Train Loss: 5.128602182562714
#
# Test Accuracy: 0.6427306391885365
#
# Epoch 60
# -------------------------------
# Train Accuracy: 0.7482848172409783
# Train Loss: 4.970465045227631
#
# Test Accuracy: 0.6713894702946386
#
# Epoch 61
# -------------------------------
# Train Accuracy: 0.7284390867863095
# Train Loss: 5.014968297087324
#
# Test Accuracy: 0.6366124617613911
#
# Epoch 62
# -------------------------------
# Train Accuracy: 0.7684018760417071
# Train Loss: 4.894993867581326
#
# Test Accuracy: 0.6255031395910481
#
# Epoch 63
# -------------------------------
# Train Accuracy: 0.7483623396255669
# Train Loss: 4.920574877695665
#
# Test Accuracy: 0.6533569473514732
#
# Epoch 64
# -------------------------------
# Train Accuracy: 0.7366952207449902
# Train Loss: 4.954246791138267
#
# Test Accuracy: 0.6586701014329416
#
# Epoch 65
# -------------------------------
# Train Accuracy: 0.7585952943912555
# Train Loss: 4.925581912198058
#
# Test Accuracy: 0.6312993076799227
#
# Epoch 66
# -------------------------------
# Train Accuracy: 0.734989728284042
# Train Loss: 4.975387003242963
#
# Test Accuracy: 0.6618901948156497
#
# Epoch 67
# -------------------------------
# Train Accuracy: 0.761347339044149
# Train Loss: 4.8833621025675145
#
# Test Accuracy: 0.6738045403316696
#
# Epoch 68
# -------------------------------
# Train Accuracy: 0.7371215938602271
# Train Loss: 4.982981438744868
#
# Test Accuracy: 0.6446626952181613
#
# Epoch 69
# -------------------------------
# Train Accuracy: 0.7694096670413582
# Train Loss: 4.879221098860053
#
# Test Accuracy: 0.6749315730156175
#
# Epoch 70
# -------------------------------
# Train Accuracy: 0.7701461296949494
# Train Loss: 4.883585947379978
#
# Test Accuracy: 0.7063274834970215
#
# Epoch 71
# -------------------------------
# Train Accuracy: 0.7698360401565952
# Train Loss: 4.887438831602353
#
# Test Accuracy: 0.6770246337143777
#
# Epoch 72
# -------------------------------
# Train Accuracy: 0.7567735183534245
# Train Loss: 4.952245887832083
#
# Test Accuracy: 0.6441796812107551
#
# Epoch 73
# -------------------------------
# Train Accuracy: 0.7507267723555177
# Train Loss: 4.950059487216911
#
# Test Accuracy: 0.6519079053292546
#
# Epoch 74
# -------------------------------
# Train Accuracy: 0.7596806077754952
# Train Loss: 4.8964039911594694
#
# Test Accuracy: 0.6710674609563677
#
# Epoch 75
# -------------------------------
# Train Accuracy: 0.8035582774526144
# Train Loss: 4.805542444424449
#
# Test Accuracy: 0.6100466913540493
#
# Epoch 76
# -------------------------------
# Train Accuracy: 0.784604054420714
# Train Loss: 4.849832160720633
#
# Test Accuracy: 0.6667203348897118
#
# Epoch 77
# -------------------------------
# Train Accuracy: 0.7932478003023373
# Train Loss: 4.8146212874664105
#
# Test Accuracy: 0.6348414104009016
#
# Epoch 78
# -------------------------------
# Train Accuracy: 0.7877437109965503
# Train Loss: 4.824494931160227
#
# Test Accuracy: 0.6169698921268717
#
# Epoch 79
# -------------------------------
# Train Accuracy: 0.7964262180704679
# Train Loss: 4.802581327425187
#
# Test Accuracy: 0.666398325551441
#
# Epoch 80
# -------------------------------
# Train Accuracy: 0.7397961161285321
# Train Loss: 4.963776904625388
#
# Test Accuracy: 0.6238930928996941
#
# Epoch 81
# -------------------------------
# Train Accuracy: 0.7574324586224273
# Train Loss: 4.900564603197267
#
# Test Accuracy: 0.6166478827886008
#
# Epoch 82
# -------------------------------
# Train Accuracy: 0.7665413388115818
# Train Loss: 4.903834741937888
#
# Test Accuracy: 0.6738045403316696
#
# Epoch 83
# -------------------------------
# Train Accuracy: 0.7776270398077445
# Train Loss: 4.81564761033117
#
# Test Accuracy: 0.7056834648204798
#
# Epoch 84
# -------------------------------
# Train Accuracy: 0.7908833675723865
# Train Loss: 4.805426492488349
#
# Test Accuracy: 0.6960231846723555
#
# Epoch 85
# -------------------------------
# Train Accuracy: 0.7088646846777007
# Train Loss: 5.038262993757516
#
# Test Accuracy: 0.6742875543390758
#
# Epoch 86
# -------------------------------
# Train Accuracy: 0.7620838016977403
# Train Loss: 4.870386974149481
#
# Test Accuracy: 0.6140718080824344
#
# Epoch 87
# -------------------------------
# Train Accuracy: 0.7508430559324005
# Train Loss: 4.94854237692245
#
# Test Accuracy: 0.665593302205764
#
# Epoch 88
# -------------------------------
# Train Accuracy: 0.7831311291135316
# Train Loss: 4.8389071403775255
#
# Test Accuracy: 0.6108517146997263
#
# Epoch 89
# -------------------------------
# Train Accuracy: 0.763324159851157
# Train Loss: 4.890812129946753
#
# Test Accuracy: 0.7203348897118016
#
# Epoch 90
# -------------------------------
# Train Accuracy: 0.7953021434939339
# Train Loss: 4.751331079779553
#
# Test Accuracy: 0.6263081629367252
#
# Epoch 91
# -------------------------------
# Train Accuracy: 0.7812705918834063
# Train Loss: 4.858652538340859
#
# Test Accuracy: 0.6623732088230558
#
# Epoch 92
# -------------------------------
# Train Accuracy: 0.7777820845769216
# Train Loss: 4.897440123260682
#
# Test Accuracy: 0.670745451618097
#
# Epoch 93
# -------------------------------
# Train Accuracy: 0.7772006666925074
# Train Loss: 4.891051022874234
#
# Test Accuracy: 0.6597971341168893
#
# Epoch 94
# -------------------------------
# Train Accuracy: 0.773479592232257
# Train Loss: 4.868237111070569
#
# Test Accuracy: 0.6779906617291901
#
# Epoch 95
# -------------------------------
# Train Accuracy: 0.7547966975464165
# Train Loss: 4.946390672702586
#
# Test Accuracy: 0.6171308967960071
#
# Epoch 96
# -------------------------------
# Train Accuracy: 0.7979379045699446
# Train Loss: 4.776872125059799
#
# Test Accuracy: 0.6726775076477218
#
# Epoch 97
# -------------------------------
# Train Accuracy: 0.8141788441412457
# Train Loss: 4.7336588638471815
#
# Test Accuracy: 0.6457897279021092
#
# Epoch 98
# -------------------------------
# Train Accuracy: 0.8077057250281019
# Train Loss: 4.757318686860711
#
# Test Accuracy: 0.6796007084205442
#
# Epoch 99
# -------------------------------
# Train Accuracy: 0.7611922942749719
# Train Loss: 4.837688792210068
#
# Test Accuracy: 0.6412815971663178
#
# Epoch 100
# -------------------------------
# Train Accuracy: 0.7631303538896856
# Train Loss: 4.914452566103924
#
# Test Accuracy: 0.6129447753984866
#
# Epoch 101
# -------------------------------
# Train Accuracy: 0.7751075623086167
# Train Loss: 4.871287122024267
#
# Test Accuracy: 0.6372564804379327
#
# Epoch 102
# -------------------------------
# Train Accuracy: 0.7693321446567697
# Train Loss: 4.924927629172192
#
# Test Accuracy: 0.6269521816132668
#
# Epoch 103
# -------------------------------
# Train Accuracy: 0.8153804411023683
# Train Loss: 4.745994099095105
#
# Test Accuracy: 0.6873289325390436
#
# Epoch 104
# -------------------------------
# Train Accuracy: 0.7749137563471452
# Train Loss: 4.878093721427763
#
# Test Accuracy: 0.6493318306230881
#
# Epoch 105
# -------------------------------
# Train Accuracy: 0.7703011744641265
# Train Loss: 4.878927367380212
#
# Test Accuracy: 0.65206890999839
#
# Epoch 106
# -------------------------------
# Train Accuracy: 0.7957672778014652
# Train Loss: 4.825860517850283
#
# Test Accuracy: 0.7034293994525841
#
# Epoch 107
# -------------------------------
# Train Accuracy: 0.7720066669250746
# Train Loss: 4.910223518054104
#
# Test Accuracy: 0.6543229753662856
#
# Epoch 108
# -------------------------------
# Train Accuracy: 0.783053606728943
# Train Loss: 4.836539603656709
#
# Test Accuracy: 0.6449847045564321
#
# Epoch 109
# -------------------------------
# Train Accuracy: 0.775456413039265
# Train Loss: 4.8488139111978725
#
# Test Accuracy: 0.6540009660280148
#
# Epoch 110
# -------------------------------
# Train Accuracy: 0.7536338617775883
# Train Loss: 4.930543375333791
#
# Test Accuracy: 0.6747705683464821
#
# Epoch 111
# -------------------------------
# Train Accuracy: 0.7968525911857048
# Train Loss: 4.758706744284259
#
# Test Accuracy: 0.6290452423120271
#
# Epoch 112
# -------------------------------
# Train Accuracy: 0.7834412186518858
# Train Loss: 4.831955704422988
#
# Test Accuracy: 0.6606021574625665
#
# Epoch 113
# -------------------------------
# Train Accuracy: 0.7718128609636032
# Train Loss: 4.777621319616155
#
# Test Accuracy: 0.678312671067461
#
# Epoch 114
# -------------------------------
# Train Accuracy: 0.7891778751114384
# Train Loss: 4.796155930011965
#
# Test Accuracy: 0.6697794236032845
#
# Epoch 115
# -------------------------------
# Train Accuracy: 0.7970851583394705
# Train Loss: 4.810847976714736
#
# Test Accuracy: 0.6530349380132023
#
# Epoch 116
# -------------------------------
# Train Accuracy: 0.7973564866855305
# Train Loss: 4.777549669235441
#
# Test Accuracy: 0.7150217356303333
#
# Epoch 117
# -------------------------------
# Train Accuracy: 0.7796813829993411
# Train Loss: 4.866091566674829
#
# Test Accuracy: 0.6853968765094187
#
# Epoch 118
# -------------------------------
# Train Accuracy: 0.7697585177720067
# Train Loss: 4.855083857743059
#
# Test Accuracy: 0.6665593302205765
#
# Epoch 119
# -------------------------------
# Train Accuracy: 0.7575875033916043
# Train Loss: 4.886610034337671
#
# Test Accuracy: 0.6937691193044598
#
# Epoch 120
# -------------------------------
# Train Accuracy: 0.7866583976123106
# Train Loss: 4.77824289552119
#
# Test Accuracy: 0.6607631621317018
#
# Epoch 121
# -------------------------------
# Train Accuracy: 0.8037908446063801
# Train Loss: 4.7983588232554935
#
# Test Accuracy: 0.6665593302205765
#
# Epoch 122
# -------------------------------
# Train Accuracy: 0.7597581301600838
# Train Loss: 4.901868687967286
#
# Test Accuracy: 0.6680083722427951
#
# Epoch 123
# -------------------------------
# Train Accuracy: 0.8025504864529633
# Train Loss: 4.802448184141901
#
# Test Accuracy: 0.6928030912896475
#
# Epoch 124
# -------------------------------
# Train Accuracy: 0.7661149656963449
# Train Loss: 4.850521610469266
#
# Test Accuracy: 0.7140557076155208
#
# Epoch 125
# -------------------------------
# Train Accuracy: 0.7756114578084422
# Train Loss: 4.828778365784924
#
# Test Accuracy: 0.6889389792303977
#
# Epoch 126
# -------------------------------
# Train Accuracy: 0.7941393077251057
# Train Loss: 4.815492019323081
#
# Test Accuracy: 0.6870069232007728
#
# Epoch 127
# -------------------------------
# Train Accuracy: 0.7860382185356022
# Train Loss: 4.818174539049502
#
# Test Accuracy: 0.7006923200772822
#
# Epoch 128
# -------------------------------
# Train Accuracy: 0.7796813829993411
# Train Loss: 4.808470743494986
#
# Test Accuracy: 0.6863629045242312
#
# Epoch 129
# -------------------------------
# Train Accuracy: 0.7845265320361254
# Train Loss: 4.851176259457715
#
# Test Accuracy: 0.6717114796329093
#
# Epoch 130
# -------------------------------
# Train Accuracy: 0.8014651730687236
# Train Loss: 4.7438129067743935
#
# Test Accuracy: 0.677507647721784
#
# Epoch 131
# -------------------------------
# Train Accuracy: 0.7766192488080933
# Train Loss: 4.831222707722313
#
# Test Accuracy: 0.6304942843342457
#
# Epoch 132
# -------------------------------
# Train Accuracy: 0.7928989495716888
# Train Loss: 4.7893507801479105
#
# Test Accuracy: 0.6931251006279182
#
# Epoch 133
# -------------------------------
# Train Accuracy: 0.7802240396914609
# Train Loss: 4.794233702992767
#
# Test Accuracy: 0.6738045403316696
#
# Epoch 134
# -------------------------------
# Train Accuracy: 0.7874336214581961
# Train Loss: 4.823048726397776
#
# Test Accuracy: 0.6184189341490903
#
# Epoch 135
# -------------------------------
# Train Accuracy: 0.7959223225706423
# Train Loss: 4.752279453292377
#
# Test Accuracy: 0.65206890999839
#
# Epoch 136
# -------------------------------
# Train Accuracy: 0.7962711733012907
# Train Loss: 4.754034406981906
#
# Test Accuracy: 0.6660763162131702
#
# Epoch 137
# -------------------------------
# Train Accuracy: 0.8234427690995775
# Train Loss: 4.682728668624982
#
# Test Accuracy: 0.6662373208823056
#
# Epoch 138
# -------------------------------
# Train Accuracy: 0.7913485018799178
# Train Loss: 4.797769322186504
#
# Test Accuracy: 0.6477217839317341
#
# Epoch 139
# -------------------------------
# Train Accuracy: 0.8004961432613668
# Train Loss: 4.779181565959256
#
# Test Accuracy: 0.614715826758976
#
# Epoch 140
# -------------------------------
# Train Accuracy: 0.8194503662932672
# Train Loss: 4.658299070610937
#
# Test Accuracy: 0.6322653356947352
#
# Epoch 141
# -------------------------------
# Train Accuracy: 0.783053606728943
# Train Loss: 4.781398900926451
#
# Test Accuracy: 0.6630172274995975
#
# Epoch 142
# -------------------------------
# Train Accuracy: 0.8063878444900965
# Train Loss: 4.72438911938056
#
# Test Accuracy: 0.6301722749959748
#
# Epoch 143
# -------------------------------
# Train Accuracy: 0.7954959494554052
# Train Loss: 4.781192078728031
#
# Test Accuracy: 0.6002254065367896
#
# Epoch 144
# -------------------------------
# Train Accuracy: 0.7565409511996589
# Train Loss: 4.893811422521127
#
# Test Accuracy: 0.6243761069071003
#
# Epoch 145
# -------------------------------
# Train Accuracy: 0.8032869491065545
# Train Loss: 4.826992959440607
#
# Test Accuracy: 0.6031234905812268
#
# Epoch 146
# -------------------------------
# Train Accuracy: 0.7991782627233613
# Train Loss: 4.743759875443659
#
# Test Accuracy: 0.6712284656255031
#
# Epoch 147
# -------------------------------
# Train Accuracy: 0.803635799837203
# Train Loss: 4.7194970274725865
#
# Test Accuracy: 0.6491708259539527
#
# Epoch 148
# -------------------------------
# Train Accuracy: 0.8058064266056824
# Train Loss: 4.784804623243639
#
# Test Accuracy: 0.6369344710996618
#
# Epoch 149
# -------------------------------
# Train Accuracy: 0.8313500523276096
# Train Loss: 4.646639408796711
#
# Test Accuracy: 0.6982772500402512
#
# Epoch 150
# -------------------------------
# Train Accuracy: 0.8092561727198728
# Train Loss: 4.71383584565231
#
# Test Accuracy: 0.639349541136693
#
# Epoch 151
# -------------------------------
# Train Accuracy: 0.7999922477615411
# Train Loss: 4.765826916867954
#
# Test Accuracy: 0.6924810819513766
#
# Epoch 152
# -------------------------------
# Train Accuracy: 0.7913097406876235
# Train Loss: 4.820056531536315
#
# Test Accuracy: 0.6311383030107873
#
# Epoch 153
# -------------------------------
# Train Accuracy: 0.7887515019962014
# Train Loss: 4.818711592157045
#
# Test Accuracy: 0.6387055224601513
#
# Epoch 154
# -------------------------------
# Train Accuracy: 0.8239079034071088
# Train Loss: 4.647790425266627
#
# Test Accuracy: 0.6501368539687651
#
# Epoch 155
# -------------------------------
# Train Accuracy: 0.791232218303035
# Train Loss: 4.750273482237468
#
# Test Accuracy: 0.6760586056995653
#
# Epoch 156
# -------------------------------
# Train Accuracy: 0.808713516027753
# Train Loss: 4.714292773964112
#
# Test Accuracy: 0.6559330220576397
#
# Epoch 157
# -------------------------------
# Train Accuracy: 0.805612620644211
# Train Loss: 4.70196459444812
#
# Test Accuracy: 0.716470777652552
#
# Epoch 158
# -------------------------------
# Train Accuracy: 0.8289080972130702
# Train Loss: 4.687769050127416
#
# Test Accuracy: 0.6890999838995331
#
# Epoch 159
# -------------------------------
# Train Accuracy: 0.8001472925307183
# Train Loss: 4.786735051825874
#
# Test Accuracy: 0.6562550313959105
#
# Epoch 160
# -------------------------------
# Train Accuracy: 0.7968525911857048
# Train Loss: 4.764019091757363
#
# Test Accuracy: 0.6482047979391402
#
# Epoch 161
# -------------------------------
# Train Accuracy: 0.8034419938757316
# Train Loss: 4.721759718148442
#
# Test Accuracy: 0.6948961519884077
#
# Epoch 162
# -------------------------------
# Train Accuracy: 0.8107678592193496
# Train Loss: 4.695089133201095
#
# Test Accuracy: 0.7079375301883755
#
# Epoch 163
# -------------------------------
# Train Accuracy: 0.8363114849412768
# Train Loss: 4.625926663184703
#
# Test Accuracy: 0.6884559652229915
#
# Epoch 164
# -------------------------------
# Train Accuracy: 0.7979766657622388
# Train Loss: 4.708271188659279
#
# Test Accuracy: 0.6948961519884077
#
# Epoch 165
# -------------------------------
# Train Accuracy: 0.8336757238652661
# Train Loss: 4.6765609666416355
#
# Test Accuracy: 0.6921590726131058
#
# Epoch 166
# -------------------------------
# Train Accuracy: 0.8133260979107717
# Train Loss: 4.727132637856851
#
# Test Accuracy: 0.6314603123490581
#
# Epoch 167
# -------------------------------
# Train Accuracy: 0.8175510678708477
# Train Loss: 4.67758297455382
#
# Test Accuracy: 0.6684913862502012
#
# Epoch 168
# -------------------------------
# Train Accuracy: 0.8200317841776813
# Train Loss: 4.667798547428141
#
# Test Accuracy: 0.6792786990822733
#
# Epoch 169
# -------------------------------
# Train Accuracy: 0.8244117989069344
# Train Loss: 4.660684375550105
#
# Test Accuracy: 0.6509418773144421
#
# Epoch 170
# -------------------------------
# Train Accuracy: 0.8181324857552619
# Train Loss: 4.736485815742028
#
# Test Accuracy: 0.6618901948156497
#
# Epoch 171
# -------------------------------
# Train Accuracy: 0.8066591728361564
# Train Loss: 4.757459567840766
#
# Test Accuracy: 0.6607631621317018
#
# Epoch 172
# -------------------------------
# Train Accuracy: 0.7754176518469709
# Train Loss: 4.770911283675117
#
# Test Accuracy: 0.6760586056995653
#
# Epoch 173
# -------------------------------
# Train Accuracy: 0.8179774409860847
# Train Loss: 4.660478365159057
#
# Test Accuracy: 0.6651102881983577
#
# Epoch 174
# -------------------------------
# Train Accuracy: 0.8091786503352844
# Train Loss: 4.6721723746725825
#
# Test Accuracy: 0.6676863629045242
#
# Epoch 175
# -------------------------------
# Train Accuracy: 0.7920849645335091
# Train Loss: 4.803799756429118
#
# Test Accuracy: 0.6589921107712123
#
# Epoch 176
# -------------------------------
# Train Accuracy: 0.812938485987829
# Train Loss: 4.708991270873846
#
# Test Accuracy: 0.6449847045564321
#
# Epoch 177
# -------------------------------
# Train Accuracy: 0.8010000387611923
# Train Loss: 4.749620480060548
#
# Test Accuracy: 0.6391885364675576
#
# Epoch 178
# -------------------------------
# Train Accuracy: 0.8025892476452575
# Train Loss: 4.72839757483134
#
# Test Accuracy: 0.6813717597810337
#
# Epoch 179
# -------------------------------
# Train Accuracy: 0.7996046358385984
# Train Loss: 4.745495938888976
#
# Test Accuracy: 0.643696667203349
#
# Epoch 180
# -------------------------------
# Train Accuracy: 0.7923175316872747
# Train Loss: 4.808798231044425
#
# Test Accuracy: 0.673160521655128
#
# Epoch 181
# -------------------------------
# Train Accuracy: 0.800108531338424
# Train Loss: 4.710504101999422
#
# Test Accuracy: 0.6443406858798905
#
# Epoch 182
# -------------------------------
# Train Accuracy: 0.799682158223187
# Train Loss: 4.7679234214331725
#
# Test Accuracy: 0.660441152793431
#
# Epoch 183
# -------------------------------
# Train Accuracy: 0.7711151595023062
# Train Loss: 4.795434795125517
#
# Test Accuracy: 0.6557720173885042
#
# Epoch 184
# -------------------------------
# Train Accuracy: 0.8315826194813752
# Train Loss: 4.644894902320101
#
# Test Accuracy: 0.693447109966189
#
# Epoch 185
# -------------------------------
# Train Accuracy: 0.8025892476452575
# Train Loss: 4.71156499298195
#
# Test Accuracy: 0.6607631621317018
#
# Epoch 186
# -------------------------------
# Train Accuracy: 0.7948757703786968
# Train Loss: 4.72676354801752
#
# Test Accuracy: 0.6928030912896475
#
# Epoch 187
# -------------------------------
# Train Accuracy: 0.8349548432109771
# Train Loss: 4.600135987853474
#
# Test Accuracy: 0.6354854290774432
#
# Epoch 188
# -------------------------------
# Train Accuracy: 0.8064266056823908
# Train Loss: 4.702914869073747
#
# Test Accuracy: 0.6606021574625665
#
# Epoch 189
# -------------------------------
# Train Accuracy: 0.8116206054498236
# Train Loss: 4.69969269692564
#
# Test Accuracy: 0.6591531154403478
#
# Epoch 190
# -------------------------------
# Train Accuracy: 0.8089848443738129
# Train Loss: 4.687455932550963
#
# Test Accuracy: 0.6615681854773788
#
# Epoch 191
# -------------------------------
# Train Accuracy: 0.805612620644211
# Train Loss: 4.720234190441213
#
# Test Accuracy: 0.6784736757365963
#
# Epoch 192
# -------------------------------
# Train Accuracy: 0.8104577696809954
# Train Loss: 4.714956749781958
#
# Test Accuracy: 0.6374174851070681
#
# Epoch 193
# -------------------------------
# Train Accuracy: 0.8018527849916663
# Train Loss: 4.716142679164959
#
# Test Accuracy: 0.712123651585896
#
# Epoch 194
# -------------------------------
# Train Accuracy: 0.8240241869839916
# Train Loss: 4.633800755568219
#
# Test Accuracy: 0.6586701014329416
#
# Epoch 195
# -------------------------------
# Train Accuracy: 0.7925888600333346
# Train Loss: 4.795302697248578
#
# Test Accuracy: 0.6697794236032845
#
# Epoch 196
# -------------------------------
# Train Accuracy: 0.8005736656459552
# Train Loss: 4.761421940896298
#
# Test Accuracy: 0.7079375301883755
#
# Epoch 197
# -------------------------------
# Train Accuracy: 0.8234040079072832
# Train Loss: 4.678095706700788
#
# Test Accuracy: 0.6404765738206408
#
# Epoch 198
# -------------------------------
# Train Accuracy: 0.7928214271871002
# Train Loss: 4.712459370072665
#
# Test Accuracy: 0.6279182096280792
#
# Epoch 199
# -------------------------------
# Train Accuracy: 0.8335594402883832
# Train Loss: 4.598281105816149
#
# Test Accuracy: 0.6472387699243278
#
# Epoch 200
# -------------------------------
# Train Accuracy: 0.8268149928291795
# Train Loss: 4.671912983906646
#
# Test Accuracy: 0.7108356142328127
#
# Epoch 201
# -------------------------------
# Train Accuracy: 0.8090623667584015
# Train Loss: 4.675215444567472
#
# Test Accuracy: 0.6712284656255031
#
# Epoch 202
# -------------------------------
# Train Accuracy: 0.8033644714911431
# Train Loss: 4.746427148614035
#
# Test Accuracy: 0.7254870391241346
#
# Epoch 203
# -------------------------------
# Train Accuracy: 0.795457188263111
# Train Loss: 4.723104914284366
#
# Test Accuracy: 0.7296731605216551
#
# Epoch 204
# -------------------------------
# Train Accuracy: 0.8239079034071088
# Train Loss: 4.639770242242644
#
# Test Accuracy: 0.6865239091933666
#
# Epoch 205
# -------------------------------
# Train Accuracy: 0.8143726501027172
# Train Loss: 4.711217158216066
#
# Test Accuracy: 0.6636612461761391
#
# Epoch 206
# -------------------------------
# Train Accuracy: 0.8069305011822163
# Train Loss: 4.722304457684947
#
# Test Accuracy: 0.6721944936403156
#
# Epoch 207
# -------------------------------
# Train Accuracy: 0.8286755300593046
# Train Loss: 4.702603078354396
#
# Test Accuracy: 0.6684913862502012
#
# Epoch 208
# -------------------------------
# Train Accuracy: 0.7972402031086476
# Train Loss: 4.751332319247551
#
# Test Accuracy: 0.6728385123168572
#
# Epoch 209
# -------------------------------
# Train Accuracy: 0.8260785301755882
# Train Loss: 4.6643946506938985
#
# Test Accuracy: 0.6865239091933666
#
# Epoch 210
# -------------------------------
# Train Accuracy: 0.8166983216403737
# Train Loss: 4.719296931300705
#
# Test Accuracy: 0.6762196103687007
#
# Epoch 211
# -------------------------------
# Train Accuracy: 0.7918136361874492
# Train Loss: 4.7822949871595135
#
# Test Accuracy: 0.6486878119465465
#
# Epoch 212
# -------------------------------
# Train Accuracy: 0.8170084111787279
# Train Loss: 4.692003236973845
#
# Test Accuracy: 0.7201738850426662
#
# Epoch 213
# -------------------------------
# Train Accuracy: 0.7979379045699446
# Train Loss: 4.69929078044893
#
# Test Accuracy: 0.6794397037514088
#
# Epoch 214
# -------------------------------
# Train Accuracy: 0.8389860072095817
# Train Loss: 4.633406259421465
#
# Test Accuracy: 0.7052004508130736
#
# Epoch 215
# -------------------------------
# Train Accuracy: 0.81421760533354
# Train Loss: 4.685929014956961
#
# Test Accuracy: 0.705361455482209
#
# Epoch 216
# -------------------------------
# Train Accuracy: 0.8156130082561339
# Train Loss: 4.655964173423916
#
# Test Accuracy: 0.640959587828047
#
# Epoch 217
# -------------------------------
# Train Accuracy: 0.842823365246715
# Train Loss: 4.595605489216065
#
# Test Accuracy: 0.6849138625020126
#
# Epoch 218
# -------------------------------
# Train Accuracy: 0.8125508740648862
# Train Loss: 4.719970557019329
#
# Test Accuracy: 0.677507647721784
#
# Epoch 219
# -------------------------------
# Train Accuracy: 0.8228613512151634
# Train Loss: 4.76268233821595
#
# Test Accuracy: 0.6950571566575431
#
# Epoch 220
# -------------------------------
# Train Accuracy: 0.8300709329818985
# Train Loss: 4.629929138963519
#
# Test Accuracy: 0.6789566897440026
#
# Epoch 221
# -------------------------------
# Train Accuracy: 0.8380557385945192
# Train Loss: 4.612718791185463
#
# Test Accuracy: 0.7010143294155531
#
# Epoch 222
# -------------------------------
# Train Accuracy: 0.8410403504011783
# Train Loss: 4.628406286867303
#
# Test Accuracy: 0.6255031395910481
#
# Epoch 223
# -------------------------------
# Train Accuracy: 0.8402651265552928
# Train Loss: 4.578940558803119
#
# Test Accuracy: 0.6710674609563677
#
# Epoch 224
# -------------------------------
# Train Accuracy: 0.8339082910190317
# Train Loss: 4.651567910475882
#
# Test Accuracy: 0.7126066655933022
#
# Epoch 225
# -------------------------------
# Train Accuracy: 0.827745261444242
# Train Loss: 4.63073630331307
#
# Test Accuracy: 0.6855578811785542
#
# Epoch 226
# -------------------------------
# Train Accuracy: 0.8044885460676771
# Train Loss: 4.6879983610903055
#
# Test Accuracy: 0.6646272741909516
#
# Epoch 227
# -------------------------------
# Train Accuracy: 0.8328617388270864
# Train Loss: 4.639761592007054
#
# Test Accuracy: 0.6960231846723555
#
# Epoch 228
# -------------------------------
# Train Accuracy: 0.8369316640179852
# Train Loss: 4.639888898783367
#
# Test Accuracy: 0.6717114796329093
#
# Epoch 229
# -------------------------------
# Train Accuracy: 0.8092561727198728
# Train Loss: 4.7350441705225235
#
# Test Accuracy: 0.7108356142328127
#
# Epoch 230
# -------------------------------
# Train Accuracy: 0.8203418737160355
# Train Loss: 4.654767724415927
#
# Test Accuracy: 0.6509418773144421
#
# Epoch 231
# -------------------------------
# Train Accuracy: 0.8263110973293538
# Train Loss: 4.601241218399384
#
# Test Accuracy: 0.6939301239735952
#
# Epoch 232
# -------------------------------
# Train Accuracy: 0.8369704252102794
# Train Loss: 4.583661389591338
#
# Test Accuracy: 0.6654322975366286
#
# Epoch 233
# -------------------------------
# Train Accuracy: 0.8208845304081553
# Train Loss: 4.649957047627976
#
# Test Accuracy: 0.6820157784575752
#
# Epoch 234
# -------------------------------
# Train Accuracy: 0.8379782162099306
# Train Loss: 4.603367767293314
#
# Test Accuracy: 0.6306552890033811
#
# Epoch 235
# -------------------------------
# Train Accuracy: 0.832396604519555
# Train Loss: 4.658986270879597
#
# Test Accuracy: 0.6583480920946707
#
# Epoch 236
# -------------------------------
# Train Accuracy: 0.8085972324508702
# Train Loss: 4.728235331577531
#
# Test Accuracy: 0.724037997101916
#
# Epoch 237
# -------------------------------
# Train Accuracy: 0.8442187681693089
# Train Loss: 4.584132222807024
#
# Test Accuracy: 0.6889389792303977
#
# Epoch 238
# -------------------------------
# Train Accuracy: 0.8378231714407535
# Train Loss: 4.65107189156793
#
# Test Accuracy: 0.6533569473514732
#
# Epoch 239
# -------------------------------
# Train Accuracy: 0.8279390674057134
# Train Loss: 4.6373218613905065
#
# Test Accuracy: 0.6863629045242312
#
# Epoch 240
# -------------------------------
# Train Accuracy: 0.8421644249777123
# Train Loss: 4.654460703113234
#
# Test Accuracy: 0.614715826758976
#
# Epoch 241
# -------------------------------
# Train Accuracy: 0.8451102755920772
# Train Loss: 4.572734396676482
#
# Test Accuracy: 0.6535179520206086
#
# Epoch 242
# -------------------------------
# Train Accuracy: 0.827318888329005
# Train Loss: 4.670696280902072
#
# Test Accuracy: 0.6863629045242312
#
# Epoch 243
# -------------------------------
# Train Accuracy: 0.8069692623745106
# Train Loss: 4.66789793002318
#
# Test Accuracy: 0.6665593302205765
#
# Epoch 244
# -------------------------------
# Train Accuracy: 0.8293732315206016
# Train Loss: 4.627861808665215
#
# Test Accuracy: 0.6533569473514732
#
# Epoch 245
# -------------------------------
# Train Accuracy: 0.8309624404046668
# Train Loss: 4.635657916018734
#
# Test Accuracy: 0.6899050072452101
#
# Epoch 246
# -------------------------------
# Train Accuracy: 0.8245668436761114
# Train Loss: 4.671943385989524
#
# Test Accuracy: 0.6762196103687007
#
# Epoch 247
# -------------------------------
# Train Accuracy: 0.812512112872592
# Train Loss: 4.700024115500511
#
# Test Accuracy: 0.6530349380132023
#
# Epoch 248
# -------------------------------
# Train Accuracy: 0.8112329935268809
# Train Loss: 4.67120164359171
#
# Test Accuracy: 0.6282402189663501
#
# Epoch 249
# -------------------------------
# Train Accuracy: 0.8241792317531688
# Train Loss: 4.663498341941899
#
# Test Accuracy: 0.6810497504427628
#
# Epoch 250
# -------------------------------
# Train Accuracy: 0.8116981278344122
# Train Loss: 4.706827265570501
#
# Test Accuracy: 0.6383835131218806
#
# Epoch 251
# -------------------------------
# Train Accuracy: 0.805457575875034
# Train Loss: 4.717832111393061
#
# Test Accuracy: 0.6686523909193367
#
# Epoch 252
# -------------------------------
# Train Accuracy: 0.8234427690995775
# Train Loss: 4.602940195881807
#
# Test Accuracy: 0.6837868298180647
#
# Epoch 253
# -------------------------------
# Train Accuracy: 0.8163882321020195
# Train Loss: 4.706642790418654
#
# Test Accuracy: 0.651263886652713
#
# Epoch 254
# -------------------------------
# Train Accuracy: 0.8340245745959146
# Train Loss: 4.637285378650135
#
# Test Accuracy: 0.6826597971341168
#
# Epoch 255
# -------------------------------
# Train Accuracy: 0.8118531726035892
# Train Loss: 4.722171127605262
#
# Test Accuracy: 0.6765416197069715
#
# Epoch 256
# -------------------------------
# Train Accuracy: 0.8396449474785844
# Train Loss: 4.611458090378474
#
# Test Accuracy: 0.6673643535662535
#
# Epoch 257
# -------------------------------
# Train Accuracy: 0.8220861273692779
# Train Loss: 4.635996364653273
#
# Test Accuracy: 0.6316213170181936
#
# Epoch 258
# -------------------------------
# Train Accuracy: 0.8369316640179852
# Train Loss: 4.613859509221761
#
# Test Accuracy: 0.6591531154403478
#
# Epoch 259
# -------------------------------
# Train Accuracy: 0.7983642776851816
# Train Loss: 4.7623443891650945
#
# Test Accuracy: 0.6713894702946386
#
# Epoch 260
# -------------------------------
# Train Accuracy: 0.8423194697468894
# Train Loss: 4.593565334181722
#
# Test Accuracy: 0.6345194010626308
#
# Epoch 261
# -------------------------------
# Train Accuracy: 0.805457575875034
# Train Loss: 4.6937277508749
#
# Test Accuracy: 0.6490098212848172
#
# Epoch 262
# -------------------------------
# Train Accuracy: 0.8290243807899531
# Train Loss: 4.62771425197295
#
# Test Accuracy: 0.712928674931573
#
# Epoch 263
# -------------------------------
# Train Accuracy: 0.8317764254428466
# Train Loss: 4.638461716647415
#
# Test Accuracy: 0.6343583963934954
#
# Epoch 264
# -------------------------------
# Train Accuracy: 0.8108453816039382
# Train Loss: 4.704098986655086
#
# Test Accuracy: 0.6284012236354855
#
# Epoch 265
# -------------------------------
# Train Accuracy: 0.8281716345594791
# Train Loss: 4.6254304599245035
#
# Test Accuracy: 0.6607631621317018
#
# Epoch 266
# -------------------------------
# Train Accuracy: 0.8356913058645684
# Train Loss: 4.622095792321511
#
# Test Accuracy: 0.6635002415070037
#
# Epoch 267
# -------------------------------
# Train Accuracy: 0.826466142098531
# Train Loss: 4.625585282099489
#
# Test Accuracy: 0.673160521655128
#
# Epoch 268
# -------------------------------
# Train Accuracy: 0.8248769332144656
# Train Loss: 4.659730966946754
#
# Test Accuracy: 0.7039124134599903
#
# Epoch 269
# -------------------------------
# Train Accuracy: 0.8551881855885887
# Train Loss: 4.573385053616884
#
# Test Accuracy: 0.6575430687489937
#
# Epoch 270
# -------------------------------
# Train Accuracy: 0.809566262258227
# Train Loss: 4.68987545201441
#
# Test Accuracy: 0.6567380454033167
#
# Epoch 271
# -------------------------------
# Train Accuracy: 0.8210008139850382
# Train Loss: 4.63713313845461
#
# Test Accuracy: 0.6232490742231525
#
# Epoch 272
# -------------------------------
# Train Accuracy: 0.8116206054498236
# Train Loss: 4.691163915506365
#
# Test Accuracy: 0.6490098212848172
#
# Epoch 273
# -------------------------------
# Train Accuracy: 0.7878987557657273
# Train Loss: 4.809888864897347
#
# Test Accuracy: 0.6886169698921268
#
# Epoch 274
# -------------------------------
# Train Accuracy: 0.826466142098531
# Train Loss: 4.59137935897293
#
# Test Accuracy: 0.685879890516825
#
# Epoch 275
# -------------------------------
# Train Accuracy: 0.8232489631381061
# Train Loss: 4.63615291048467
#
# Test Accuracy: 0.6852358718402833
#
# Epoch 276
# -------------------------------
# Train Accuracy: 0.8325128880964379
# Train Loss: 4.626567395501506
#
# Test Accuracy: 0.6815327644501691
#
# Epoch 277
# -------------------------------
# Train Accuracy: 0.8318151866351409
# Train Loss: 4.63549114224959
#
# Test Accuracy: 0.6332313637095476
#
# Epoch 278
# -------------------------------
# Train Accuracy: 0.8228225900228691
# Train Loss: 4.630636823823922
#
# Test Accuracy: 0.6982772500402512
#
# Epoch 279
# -------------------------------
# Train Accuracy: 0.8321640373657894
# Train Loss: 4.61701866532817
#
# Test Accuracy: 0.6428916438576718
#
# Epoch 280
# -------------------------------
# Train Accuracy: 0.8572812899724795
# Train Loss: 4.544926592938268
#
# Test Accuracy: 0.6776686523909193
#
# Epoch 281
# -------------------------------
# Train Accuracy: 0.841272917554944
# Train Loss: 4.552453711015474
#
# Test Accuracy: 0.6644662695218161
#
# Epoch 282
# -------------------------------
# Train Accuracy: 0.8167758440249622
# Train Loss: 4.715485668808325
#
# Test Accuracy: 0.660441152793431
#
# Epoch 283
# -------------------------------
# Train Accuracy: 0.828598007674716
# Train Loss: 4.634800842992406
#
# Test Accuracy: 0.7208179037192078
#
# Epoch 284
# -------------------------------
# Train Accuracy: 0.8320865149812008
# Train Loss: 4.626237823741546
#
# Test Accuracy: 0.627435195620673
#
# Epoch 285
# -------------------------------
# Train Accuracy: 0.7831311291135316
# Train Loss: 4.83559236823635
#
# Test Accuracy: 0.6845918531637417
#
# Epoch 286
# -------------------------------
# Train Accuracy: 0.8299546494050157
# Train Loss: 4.631652572584889
#
# Test Accuracy: 0.6662373208823056
#
# Epoch 287
# -------------------------------
# Train Accuracy: 0.8091398891429901
# Train Loss: 4.73336311228793
#
# Test Accuracy: 0.6319433263564643
#
# Epoch 288
# -------------------------------
# Train Accuracy: 0.8035970386449087
# Train Loss: 4.741026267025626
#
# Test Accuracy: 0.6808887457736275
#
# Epoch 289
# -------------------------------
# Train Accuracy: 0.8099926353734641
# Train Loss: 4.7273698761724345
#
# Test Accuracy: 0.6577040734181291
#
# Epoch 290
# -------------------------------
# Train Accuracy: 0.8162331873328423
# Train Loss: 4.667045694909406
#
# Test Accuracy: 0.6565770407341813
#
# Epoch 291
# -------------------------------
# Train Accuracy: 0.8376681266715764
# Train Loss: 4.608108224218998
#
# Test Accuracy: 0.6828208018032523
#
# Epoch 292
# -------------------------------
# Train Accuracy: 0.813209814333889
# Train Loss: 4.650726642566951
#
# Test Accuracy: 0.6546449847045565
#
# Epoch 293
# -------------------------------
# Train Accuracy: 0.834916082018683
# Train Loss: 4.604040439831515
#
# Test Accuracy: 0.6617291901465142
#
# Epoch 294
# -------------------------------
# Train Accuracy: 0.8462343501686111
# Train Loss: 4.563216308968416
#
# Test Accuracy: 0.6559330220576397
#
# Epoch 295
# -------------------------------
# Train Accuracy: 0.8265049032908253
# Train Loss: 4.684229157781587
#
# Test Accuracy: 0.6982772500402512
#
# Epoch 296
# -------------------------------
# Train Accuracy: 0.8330555447885577
# Train Loss: 4.655193792596478
#
# Test Accuracy: 0.6776686523909193
#
# Epoch 297
# -------------------------------
# Train Accuracy: 0.831970231404318
# Train Loss: 4.62762080080934
#
# Test Accuracy: 0.6833038158106585
#
# Epoch 298
# -------------------------------
# Train Accuracy: 0.804914919182914
# Train Loss: 4.749115433383496
#
# Test Accuracy: 0.6892609885686685
#
# Epoch 299
# -------------------------------
# Train Accuracy: 0.8318151866351409
# Train Loss: 4.651794553655296
#
# Test Accuracy: 0.6923200772822412
#
# Epoch 300
# -------------------------------
# Train Accuracy: 0.8088685607969301
# Train Loss: 4.68141631377314
#
# Test Accuracy: 0.6533569473514732

# %%
epochs_axis = range(1,epochs+1)

plt.plot(epochs_axis, loss_axis)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
figure(figsize=(20, 8), dpi=80)

plt.plot(epochs_axis, cindex_train, color='gold', label='train')
plt.plot(epochs_axis, cindex_test, color='g', label='test')

plt.xlabel("Epoch")
plt.ylabel("c_index")

plt.legend()

plt.show()
